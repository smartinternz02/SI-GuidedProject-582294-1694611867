# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('car_crashes.csv')
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
data.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
sns.scatterplot(x="total",y="speeding",data=data)
# Out:
# <AxesSubplot:xlabel='total', ylabel='speeding'>

# %%
sns.scatterplot(x="alcohol",y="speeding",data=data)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='speeding'>

# %%
sns.lineplot(x="speeding",y="ins_losses",data=data)
# Out:
# <AxesSubplot:xlabel='speeding', ylabel='ins_losses'>

# %%
sns.lineplot(x="alcohol",y="total",data=data)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='total'>

# %%
sns.lineplot(x="no_previous",y="total",data=data)
# Out:
# <AxesSubplot:xlabel='no_previous', ylabel='total'>

# %%
sns.lineplot(x="ins_premium",y="total",data=data)
# Out:
# <AxesSubplot:xlabel='ins_premium', ylabel='total'>

# %%
sns.lineplot(x="ins_losses",y="total",data=data)
# Out:
# <AxesSubplot:xlabel='ins_losses', ylabel='total'>

# %%
plt.subplots(figsize=(16,10))
sns.barplot(data=data,x="total",y="abbrev")
# Out:
# <AxesSubplot:xlabel='total', ylabel='abbrev'>

# %%
sns.scatterplot(x="total",y="speeding",data=data,hue="alcohol")
# Out:
# <AxesSubplot:xlabel='total', ylabel='speeding'>

# %%
sns.scatterplot(x="total",y="not_distracted",data=data,hue="no_previous")
# Out:
# <AxesSubplot:xlabel='total', ylabel='not_distracted'>

# %%
sns.scatterplot(x="total",y="speeding",data=data,hue="ins_premium")
# Out:
# <AxesSubplot:xlabel='total', ylabel='speeding'>

# %%
sns.scatterplot(x="ins_losses",y="speeding",data=data,hue="total")
# Out:
# <AxesSubplot:xlabel='ins_losses', ylabel='speeding'>

# %%
sns.jointplot(x="total",y="alcohol",data=data)

# %%
sns.jointplot(x="total",y="speeding",data=data)

# %%
sns.jointplot(x="total",y="not_distracted",data=data)

# %%
sns.jointplot(x="total",y="no_previous",data=data)

# %%
sns.jointplot(x="ins_losses",y="ins_premium",data=data)

# %%
sns.jointplot(x="ins_losses",y="ins_losses",data=data)

# %%
corr = data.corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)
